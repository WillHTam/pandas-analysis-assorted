# %%
import pandas as pd
fandango = pd.read_csv('./fandango_score.csv')

# %%
fandango.loc[:2]
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0     3.70           4.3         ...                3.90            3.5
# 1     4.25           4.0         ...                3.55            4.5
# 2     4.00           4.5         ...                3.90            4.0
#
#    RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# ...

# %%
# Shared Indexes
film_series = fandango['FILM']
rt_series = fandango['RottenTomatoes']

# %%
from pandas import Series

film_names = film_series.values
rt_scores = rt_series.values

# %%
type(rt_series)
# Out:
# pandas.core.series.Series

# %%
type(rt_scores)
# Out:
# numpy.ndarray

# %%
series_custom = Series(rt_scores, film_names)
series_custom.head()
# Out:
# Avengers: Age of Ultron (2015)    74
# Cinderella (2015)                 85
# Ant-Man (2015)                    80
# Do You Believe? (2015)            18
# Hot Tub Time Machine 2 (2015)     14
# dtype: int64

# %%
# Even though series_custom has strings for its index, it still has an internal numerical index that can be accessed
series_custom[['Minions (2015)', 'Leviathan (2014)']]
series_custom[5:11]
# Out:
# The Water Diviner (2015)             63
# Irrational Man (2015)                42
# Top Five (2014)                      86
# Shaun the Sheep Movie (2015)         99
# Love & Mercy (2015)                  89
# Far From The Madding Crowd (2015)    84
# dtype: int64

# %%
# To resort series_custom alphabetically
# Return a list representation of the current index using tolist().
original_index = series_custom.index
# Sort the index with sorted().
sorte = sorted(original_index)
# Use reindex() to set the newly-ordered index.
sorted_by_index = series_custom.reindex(sorte)
sorted_by_index.head()
# Out:
# '71 (2015)                    97
# 5 Flights Up (2015)           52
# A Little Chaos (2015)         40
# A Most Violent Year (2014)    90
# About Elly (2015)             97
# dtype: int64

# %%
# Or just use the pandas method
sc2 = series_custom.sort_index()
sc3 = series_custom.sort_values()

# %%
# Can apply numpy functions like np.add or np.max
# Or just plain operators
normalized_score = series_custom/20

# %% [markdown]
# rt_critics and rt_users are Series objects containing the average ratings from critics and users for each film.
# Both Series objects use the same custom string index, which they base on the film names. Using the Python arithmetic operators to return a new Series object, rt_mean, that contains the mean ratings from both critics and users for each film.

# %%
rt_critics = Series(fandango['RottenTomatoes'].values, index=fandango['FILM'])
rt_users = Series(fandango['RottenTomatoes_User'].values, index=fandango['FILM'])
rt_mean = (rt_critics + rt_users)/2

# %%
fandango.index
# Out:
# RangeIndex(start=0, stop=146, step=1)

# %%
# First five rows
fandango[0:5]
# From row at 140 and higher
fandango[140:]
# Just row at index 50
fandango.iloc[50]
# Just row at index 45 and 90
fandango.iloc[[45,90]]
# Out:
#                                                FILM  RottenTomatoes  \
# 45                              Tomorrowland (2015)              50
# 90  The SpongeBob Movie: Sponge Out of Water (2015)              78
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 45                   53          60              6.4   6.6             4.0
# 90                   55          62              6.5   6.1             3.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm         ...           \
# 45                   3.7      2.5          2.65         ...
# 90                   3.3      3.9          2.75         ...
#
#     IMDB_norm  RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 45       3.30            2.5                 2.5                    3.0
# 90       3.05            4.0                 3.0                    3.0
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# ...

# %%
# drop = False will keep the column set as index
# inplace = True will replace the original instead of having to assign it to a new var
fandango_films = fandango.set_index('FILM', drop=False)
print(fandango_films.index)
# Out:
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %%
fandango_films.iloc[:1]
# kept the FILM column but also has FILM for the index
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
#
#                                 Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Avengers: Age of Ultron (2015)             5.0                   4.5      3.7
#
#                                 RT_user_norm         ...           IMDB_norm  \
# FILM                                                 ...
# Avengers: Age of Ultron (2015)           4.3         ...                 3.9
#
#                                 RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)            3.5                 4.5
#
# ...

# %%
best_movies_ever = fandango_films.loc[['The Lazarus Effect (2015)', "Gett: The Trial of Viviane Amsalem (2015)", "Mr. Holmes (2015)"]]
best_movies_ever
# Out:
#                                                                                 FILM  \
# FILM
# The Lazarus Effect (2015)                                  The Lazarus Effect (2015)
# Gett: The Trial of Viviane Amsalem (2015)  Gett: The Trial of Viviane Amsalem (2015)
# Mr. Holmes (2015)                                                  Mr. Holmes (2015)
#
#                                            RottenTomatoes  \
# FILM
# The Lazarus Effect (2015)                              14
# Gett: The Trial of Viviane Amsalem (2015)             100
# Mr. Holmes (2015)                                      87
#
#                                            RottenTomatoes_User  Metacritic  \
# FILM
# The Lazarus Effect (2015)                                   23          31
# Gett: The Trial of Viviane Amsalem (2015)                   81          90
# Mr. Holmes (2015)                                           78          67
#
# ...

# %%
# Slice using either bracket notation or loc[]
fandango_films["Avengers: Age of Ultron (2015)":"Hot Tub Time Machine 2 (2015)"]
fandango_films.loc["Avengers: Age of Ultron (2015)":"Hot Tub Time Machine 2 (2015)"]

# Specific movie
fandango_films.loc['Kumiko, The Treasure Hunter (2015)']

# Selecting list of movies
movies = ['Kumiko, The Treasure Hunter (2015)', 'Do You Believe? (2015)', 'Ant-Man (2015)']
fandango_films.loc[movies]
# Out:
#                                                                   FILM  \
# FILM
# Kumiko, The Treasure Hunter (2015)  Kumiko, The Treasure Hunter (2015)
# Do You Believe? (2015)                          Do You Believe? (2015)
# Ant-Man (2015)                                          Ant-Man (2015)
#
#                                     RottenTomatoes  RottenTomatoes_User  \
# FILM
# Kumiko, The Treasure Hunter (2015)              87                   63
# Do You Believe? (2015)                          18                   84
# Ant-Man (2015)                                  80                   90
#
#                                     Metacritic  Metacritic_User  IMDB  \
# FILM
# Kumiko, The Treasure Hunter (2015)          68              6.4   6.7
# Do You Believe? (2015)                      22              4.7   5.4
# Ant-Man (2015)                              64              8.1   7.8
#
#                                     Fandango_Stars  Fandango_Ratingvalue  \
# FILM
# ...

# %% [markdown]
# ## The apply() method in pandas allows us to specify Python logic that we want to evaluate over the Series objects in a dataframe. Here

# %%
# Calculate the standard deviations for each numeric column
import numpy as np

# returns a Series of the datatypes of the columns
types = fandango_films.dtypes
# filter data types to just floats, index attributes returns just column names
float_columns = types[types.values == 'float64'].index
# use bracket notation to filter columns to just float columns
float_df = fandango_films[float_columns]

# `x` is a Series object representing a column
deviations = float_df.apply(lambda x: np.std(x))

print(deviations)
# Out:
# Metacritic_User               1.505529
# IMDB                          0.955447
# Fandango_Stars                0.538532
# Fandango_Ratingvalue          0.501106
# RT_norm                       1.503265
# RT_user_norm                  0.997787
# Metacritic_norm               0.972522
# Metacritic_user_nom           0.752765
# IMDB_norm                     0.477723
# RT_norm_round                 1.509404
# RT_user_norm_round            1.003559
# Metacritic_norm_round         0.987561
# Metacritic_user_norm_round    0.785412
# IMDB_norm_round               0.501043
# Fandango_Difference           0.152141
# dtype: float64

# %%
# just straight up doubling each column
double_df = float_df.apply(lambda x: x*2)
double_df.head(3)
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             14.2  15.6            10.0
# Cinderella (2015)                          15.0  14.2            10.0
# Ant-Man (2015)                             16.2  15.6            10.0
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                   9.0      7.4           8.6
# Cinderella (2015)                                9.0      8.5           8.0
# Ant-Man (2015)                                   9.0      8.0           9.0
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# FILM
# Avengers: Age of Ultron (2015)              6.6                  7.1
# Cinderella (2015)                           6.7                  7.5
# Ant-Man (2015)                              6.4                  8.1
#
# ...

# %%
rt_mt_user = float_df[['RT_user_norm', 'Metacritic_user_nom']]
# Need to set axis=1 so that this transformation is applied to the rows
# Applying over the rows allows us to do things like calculate the 
# standard deviation of multiple column values for each movie:
rt_mt_deviations = rt_mt_user.apply(lambda x: np.std(x), axis=1)
rt_mt_deviations[0:5]
# Out:
# FILM
# Avengers: Age of Ultron (2015)    0.375
# Cinderella (2015)                 0.125
# Ant-Man (2015)                    0.225
# Do You Believe? (2015)            0.925
# Hot Tub Time Machine 2 (2015)     0.150
# dtype: float64

# %%
rt_mt_means = rt_mt_user.apply(lambda x: np.mean(x), axis=1)
rt_mt_means[0:5]
# Out:
# FILM
# Avengers: Age of Ultron (2015)    3.925
# Cinderella (2015)                 3.875
# Ant-Man (2015)                    4.275
# Do You Believe? (2015)            3.275
# Hot Tub Time Machine 2 (2015)     1.550
# dtype: float64
