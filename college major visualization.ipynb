# %% [markdown]
# ### Dataset of graduates 2010-2012
# ### Visualizing earnings based on Major
# ---
# _Important Columns_
# - Rank - Rank by median earnings (the dataset is ordered by - this column).
# - Major_code - Major code.
# - Major - Major description.
# - Major_category - Category of major.
# - Total - Total number of people with major.
# - Sample_size - Sample size (unweighted) of full-time.
# - Men - Male graduates.
# - Women - Female graduates.
# - ShareWomen - Women as share of total.
# - Employed - Number employed.
# - Median - Median salary of full-time, year-round workers.
# - Low_wage_jobs - Number in low-wage service jobs.
# - Full_time - Number employed 35 hours or more.
# - Part_time - Number employed less than 35 hours.

# %% [markdown]
# - Do students in more popular majors make more money?
#     - Using scatter plots
# - How many majors are predominantly male? Predominantly female?
#     - Using histograms
# - Which category of majors have the most students?
#     - Using bar plots

# %%
# %matplotlib inline
import pandas as pd
recent_grads = pd.read_csv('recent-grads.csv')
first_row = recent_grads.iloc[0]
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.shape[0]
# Out:
# 173

# %%
cleaned_data_count = recent_grads.dropna()
cleaned_data_count.shape
# Out:
# (172, 21)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# By using the magic inline and this one line plot function, less typing required.
#
# Setting ax = df.plot() is not required, but allows us to access the Axes methods like .set_title()

# %%
ax0 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax0.set_title('Sample Size vs Median')

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax1.set_title('Sample Size vs Unemployment Rate')

# %%
ax2 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax2.set_title('Full Time vs Median')

# %%
ax3 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax3.set_title('Share of Women vs Unemployment Rate')

# %%
ax4 = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax4.set_title('Men vs Median')

# %%
ax5 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax5.set_title('Women vs Median')

# %%
ax6 = recent_grads.plot(x='Total', y='Median', kind='scatter')
ax6.set_title('Total vs Median')

# %% [markdown]
# We can have one line histograms like so as well

# %%
recent_grads['Sample_size'].hist(bins=20, range=(0,5000))

# %%
recent_grads['Median'].describe()
# Out:
# count       173.000000
# mean      40151.445087
# std       11470.181802
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64

# %%
fig = plt.figure()
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)
ax1.hist(recent_grads['Median'], bins=10, color='red')
ax2.hist(recent_grads['Median'], bins=25)
ax3.hist(recent_grads['Median'], bins=50, color='green')
plt.show()

# %%
recent_grads['Employed'].hist(bins=30)

# %%
recent_grads['Full_time'].hist(bins=25)

# %%
cats = ['ShareWomen', 'Unemployment_rate', 'Men', 'Women']
fig = plt.figure(figsize=(6,10))
for n in range(1, 5):
    ax = fig.add_subplot(4,1,n)
    ax = recent_grads[cats[n-1]].plot(kind='hist', bins=15, rot=40)

# %% [markdown]
# Now to use a scatter matrix plot.
# SCPs combine both scatter and histograms to visualize the distribution of individual columsn. Combine scatter plots and histograms into one grid of pots to explore potential relationships and distributions simultaneously

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f472d291470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f47608314a8>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f472d8f44e0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f472d08e710>]], dtype=object)

# %% [markdown]
# Making bar plots in pandas is much easier, only need to specify the data and the labels for each bar.
#
# Index is the rank of

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
